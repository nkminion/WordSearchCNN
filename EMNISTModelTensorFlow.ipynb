# %%
#Importing Packages and Checking GPU
import tensorflow as tf
from tensorflow.keras import layers,models
import numpy as np
from scipy import io
from tensorflow.keras.callbacks import EarlyStopping

GPUDevices = tf.config.list_physical_devices('GPU')

if GPUDevices:
	print("TensorFlow is using the GPU")
	for i,gpu in enumerate(GPUDevices):
		print(f"GPU {i} Found: {gpu.name}")
else:
	print("No GPU Devices found. TensorFlow is using the CPU")
# Out:
# No GPU Devices found. TensorFlow is using the CPU

# %%
#Loading DataSet
print("Loading EMNIST DataSet")
dataset = io.loadmat('datasets/emnist-letters.mat')
struct_dataset = dataset['dataset'][0,0]

TrainImages, TrainLabels = struct_dataset['train'][0,0]['images'], struct_dataset['train'][0,0]['labels']
TestImages, TestLabels = struct_dataset['test'][0,0]['images'], struct_dataset['test'][0,0]['labels']

TrainImages = TrainImages / 255.0
TestImages = TestImages / 255.0

TrainLabels = TrainLabels - 1
TestLabels = TestLabels - 1

TrainImages = TrainImages.reshape(len(TrainImages), 28, 28, 1)
TestImages = TestImages.reshape(len(TestImages), 28, 28, 1)

print("DataSet Loaded")
print(f"Train Images Shape: {TrainImages.shape}")
print(f"Train Labels Shape: {TrainLabels.shape}")
print(f"Test Images Shape: {TestImages.shape}")
print(f"Test Labels Shape: {TestLabels.shape}")
# Out:
# Loading EMNIST DataSet
# DataSet Loaded
# Train Images Shape: (124800, 28, 28, 1)
# Train Labels Shape: (124800, 1)
# Test Images Shape: (20800, 28, 28, 1)
# Test Labels Shape: (20800, 1)

# %%
#Creating Model
print("Creating Model")

model = models.Sequential()

#Layer 1
model.add(layers.Conv2D(32 , (3,3),input_shape = (28,28,1),padding='same',use_bias="false"))
model.add(layers.BatchNormalization())
model.add(layers.Activation("relu"))
model.add(layers.MaxPooling2D(pool_size = (2,2)))

#Layer 2
model.add(layers.Conv2D(32 , (3,3),padding='same',use_bias="false"))
model.add(layers.BatchNormalization())
model.add(layers.Activation("relu"))

#Layer 3
model.add(layers.Conv2D(64 , (3,3),padding='same',use_bias="false"))
model.add(layers.BatchNormalization())
model.add(layers.Activation("relu"))

#Layer 4
model.add(layers.Conv2D(64 , (3,3),padding='same',use_bias="false"))
model.add(layers.BatchNormalization())
model.add(layers.Activation("relu"))

#Layer 5
model.add(layers.Conv2D(64 , (3,3),padding='same',use_bias="false"))
model.add(layers.BatchNormalization())
model.add(layers.Activation("relu"))
model.add(layers.MaxPooling2D(pool_size = (2,2)))

#Flatten
model.add(layers.Flatten())

#Layer 6
model.add(layers.Dense(64))
model.add(layers.Activation("relu"))

#Layer 7
model.add(layers.Dense(32))
model.add(layers.Activation("relu"))

#Dropout
model.add(layers.Dropout(0.2))

#Layer 8
model.add(layers.Dense(26))
model.add(layers.Activation("softmax"))

model.compile(loss = "sparse_categorical_crossentropy" , optimizer = "adam" , metrics = ["accuracy"])

print("Model Created")
print("Model Summary: ")
model.summary()
# Out:
# Creating Model
# Model Created
# Model Summary:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 28, 28, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 14, 14, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 14, 14, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 14, 14, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 14, 14, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 14, 14, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_12 (Activation)      │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │       200,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_13 (Activation)      │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_14 (Activation)      │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 26)             │           858 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_15 (Activation)      │ (None, 26)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 306,650 (1.17 MB)
#  Trainable params: 306,138 (1.17 MB)
#  Non-trainable params: 512 (2.00 KB)

# %%
#Training and Saving model

print("Training Model")
EarlyStop = EarlyStopping(
	monitor = 'val_accuracy',
	patience = 5,
	verbose = 1,
	restore_best_weights = 1
)

Training = model.fit(TrainImages,TrainLabels,
					 batch_size = 256,
					 epochs = 100,
					 validation_data = (TestImages,TestLabels),
					 callbacks = [EarlyStop])
print("Training Complete")

model.save("EMNISTModel.keras")
print("Model Saved")
# Out:
# Training Model
# Epoch 1/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 35s 34ms/step - accuracy: 0.7285 - loss: 0.8840 - val_accuracy: 0.9075 - val_loss: 0.3021
# Epoch 2/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 35s 36ms/step - accuracy: 0.8811 - loss: 0.3727 - val_accuracy: 0.9033 - val_loss: 0.3106
# Epoch 3/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 37s 38ms/step - accuracy: 0.9052 - loss: 0.3001 - val_accuracy: 0.9299 - val_loss: 0.2227
# Epoch 4/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 38s 38ms/step - accuracy: 0.9157 - loss: 0.2671 - val_accuracy: 0.9342 - val_loss: 0.2105
# Epoch 5/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 37s 38ms/step - accuracy: 0.9233 - loss: 0.2415 - val_accuracy: 0.9313 - val_loss: 0.2151
# Epoch 6/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 37s 38ms/step - accuracy: 0.9282 - loss: 0.2251 - val_accuracy: 0.9354 - val_loss: 0.2037
# Epoch 7/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 36s 37ms/step - accuracy: 0.9308 - loss: 0.2126 - val_accuracy: 0.9402 - val_loss: 0.1932
# Epoch 8/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 37s 38ms/step - accuracy: 0.9344 - loss: 0.2033 - val_accuracy: 0.9357 - val_loss: 0.2135
# Epoch 9/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 36s 37ms/step - accuracy: 0.9388 - loss: 0.1879 - val_accuracy: 0.9394 - val_loss: 0.1896
# Epoch 10/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 35s 36ms/step - accuracy: 0.9420 - loss: 0.1751 - val_accuracy: 0.9399 - val_loss: 0.1980
# Epoch 11/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 37s 38ms/step - accuracy: 0.9439 - loss: 0.1716 - val_accuracy: 0.9425 - val_loss: 0.1905
# Epoch 12/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 35s 36ms/step - accuracy: 0.9456 - loss: 0.1615 - val_accuracy: 0.9413 - val_loss: 0.1914
# Epoch 13/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 35s 36ms/step - accuracy: 0.9472 - loss: 0.1567 - val_accuracy: 0.9448 - val_loss: 0.1844
# Epoch 14/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 34s 35ms/step - accuracy: 0.9501 - loss: 0.1484 - val_accuracy: 0.9434 - val_loss: 0.1943
# Epoch 15/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 35s 36ms/step - accuracy: 0.9508 - loss: 0.1438 - val_accuracy: 0.9388 - val_loss: 0.2036
# Epoch 16/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 36s 37ms/step - accuracy: 0.9523 - loss: 0.1376 - val_accuracy: 0.9419 - val_loss: 0.2042
# Epoch 17/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 36s 37ms/step - accuracy: 0.9535 - loss: 0.1315 - val_accuracy: 0.9421 - val_loss: 0.2024
# Epoch 18/100
# 975/975 ━━━━━━━━━━━━━━━━━━━━ 34s 35ms/step - accuracy: 0.9545 - loss: 0.1284 - val_accuracy: 0.9410 - val_loss: 0.1998
# Epoch 18: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Training Complete
# Model Saved

# %%
#Testing Model

print("Testing Model with inbuilt dataset")
TestLoss,TestAcc = model.evaluate(TestImages,TestLabels)
print(TestImages.shape)
print(TestImages.dtype)
print(np.min(TestImages), np.max(TestImages))
print(f"Mean: {np.mean(TestImages)}")
print(f"Test Accuracy: {TestAcc}")
print(f"Test Loss: {TestLoss}")
# Out:
# Testing Model with inbuilt dataset
# 650/650 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9448 - loss: 0.1844
# (20800, 28, 28, 1)
# float64
# 0.0 1.0
# Mean: 0.1721735874638317
# Test Accuracy: 0.9447596073150635
# Test Loss: 0.18435712158679962
