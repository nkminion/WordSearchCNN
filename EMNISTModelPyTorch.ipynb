# %%
#Importing packages and checking GPU
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader,Dataset,random_split
from torchsummary import summary
import numpy as np
from PIL import Image,ImageDraw,ImageFont
import os
from sklearn.model_selection import train_test_split

if torch.cuda.is_available():
	print("PyTorch is using the GPU")
	GPUCount = torch.cuda.device_count()
	print(f"Found {GPUCount} GPUs")

	for i in range(GPUCount):
		print(f"GPU {i} found: {torch.cuda.get_device_name(i)}")

	device = torch.device("cuda:0")
else:
	print("PyTorch is using the CPU")
	device = torch.device("cpu")

print(f"Selected Device: {device}")
# Out:
# PyTorch is using the GPU
# Found 1 GPUs
# GPU 0 found: NVIDIA GeForce RTX 5070 Laptop GPU
# Selected Device: cuda:0

# %%
#Import datasets and split into new ones

class TransformData(Dataset):
	def __init__(self,Data,transform=None):
		self.data = Data
		self.transform = transform

	def __getitem__(self, index):
		x,y = self.data[index]
		if self.transform:
			x = self.transform(x)
		return x,y

	def __len__(self):
		return len(self.data)

TrainTransform = transforms.Compose(
	[
		transforms.Grayscale(num_output_channels=1),
		transforms.ToTensor(),
  		transforms.Normalize((0.5,),(0.5,)),
		transforms.RandomErasing(p=0.1, scale=(0.02, 0.1), ratio=(0.3, 3.3), value=0),
		transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.9, 1.1))
	])

TestTransform = transforms.Compose(
	[
		transforms.Grayscale(num_output_channels=1),
		transforms.ToTensor(),
  		transforms.Normalize((0.5,),(0.5,)),
	])

ImagesDirectory = 'Dataset'

Dataset = ImageFolder(root=ImagesDirectory)

print(f"Size of custom data: {len(Dataset)}")

TrainSize = int(0.9*(len(Dataset)))
TestSize = len(Dataset)-TrainSize

TrainDataset, TestDataset = random_split(Dataset , [TrainSize, TestSize])

TrainDataset = TransformData(TrainDataset,TrainTransform)
TestDataset = TransformData(TestDataset,TestTransform)

print(f"Size of train data: {TrainSize}")
print(f"Size of test data: {TestSize}")

TrainLoader = DataLoader(TrainDataset,batch_size=128,shuffle=True)
TestLoader = DataLoader(TestDataset,batch_size=128,shuffle=False)

print("Dataset loaded successfully")
# Out:
# Size of custom data: 32890
# Size of train data: 29601
# Size of test data: 3289
# Dataset loaded successfully

# %%
#Creating Model

#Define architecture
class EMNISTModel(nn.Module):
	def __init__(self):
		super(EMNISTModel,self).__init__()

		#Layer1
		self.conv1 = nn.Conv2d(in_channels=1,out_channels=32,kernel_size=3,padding=1,bias=False)#Size does not change
		self.bn1 = nn.BatchNorm2d(num_features=32)
		self.relu1 = nn.ReLU()
		self.pool1 = nn.MaxPool2d(kernel_size=2)#Size halves into 14x14

		#Layer2
		self.conv2 = nn.Conv2d(in_channels=32,out_channels=32,kernel_size=3,padding=1,bias=False)
		self.bn2 = nn.BatchNorm2d(num_features=32)
		self.relu2 = nn.ReLU()

		#Layer3
		self.conv3 = nn.Conv2d(in_channels=32,out_channels=64,kernel_size=3,padding=1,bias=False)
		self.bn3 = nn.BatchNorm2d(num_features=64)
		self.relu3 = nn.ReLU()

		#Layer4
		self.conv4 = nn.Conv2d(in_channels=64,out_channels=64,kernel_size=3,padding=1,bias=False)
		self.bn4 = nn.BatchNorm2d(num_features=64)
		self.relu4 = nn.ReLU()

		#Layer5
		self.conv5 = nn.Conv2d(in_channels=64,out_channels=64,kernel_size=3,padding=1,bias=False)
		self.bn5 = nn.BatchNorm2d(num_features=64)
		self.relu5 = nn.ReLU()
		self.pool2 = nn.MaxPool2d(kernel_size=2)#Size halves into 7x7

		#FlattenLayer
		self.flatten = nn.Flatten()

		#Layer6
		self.fc1 = nn.Linear(in_features=64*7*7,out_features=256)
		self.relu6 = nn.ReLU()

		#Layer7
		self.fc2 = nn.Linear(in_features=256,out_features=64)
		self.relu7 = nn.ReLU()

		#DropoutLayer
		self.dropout = nn.Dropout(p=0.2)

		#Layer8
		self.fc3 = nn.Linear(in_features=64,out_features=26)

	def forward(self,x):

		#Pass through Layer1
		x = self.pool1(self.relu1(self.bn1(self.conv1(x))))

		#Pass through Layer2
		x = self.relu2(self.bn2(self.conv2(x)))

		#Pass through Layer3
		x = self.relu3(self.bn3(self.conv3(x)))

		#Pass through Layer4
		x = self.relu4(self.bn4(self.conv4(x)))

		#Pass through Layer5
		x = self.pool2(self.relu5(self.bn5(self.conv5(x))))

		#Pass through Layer5
		x = self.flatten(x)

		#Pass through Layer6
		x = self.relu6(self.fc1(x))

		#Pass through Layer7
		x = self.relu7(self.fc2(x))

		#Pass through DropoutLayer
		x = self.dropout(x)

		#Pass through Layer7
		x = self.fc3(x)

		#Return Prediction
		return x

#Create and print summary	
print("Creating EMNIST Model...")
model = EMNISTModel().to(device)
print("Model Created")

print("Model Summary: ")
summary(model,input_size=(1,28,28))

#Compile model
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(),lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer,mode='min',factor=0.1,patience=3,threshold=0.0001)
# Out:
# Creating EMNIST Model...
# Model Created
# Model Summary:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 28, 28]             288
#        BatchNorm2d-2           [-1, 32, 28, 28]              64
#               ReLU-3           [-1, 32, 28, 28]               0
#          MaxPool2d-4           [-1, 32, 14, 14]               0
#             Conv2d-5           [-1, 32, 14, 14]           9,216
#        BatchNorm2d-6           [-1, 32, 14, 14]              64
#               ReLU-7           [-1, 32, 14, 14]               0
#             Conv2d-8           [-1, 64, 14, 14]          18,432
#        BatchNorm2d-9           [-1, 64, 14, 14]             128
#              ReLU-10           [-1, 64, 14, 14]               0
#            Conv2d-11           [-1, 64, 14, 14]          36,864
#       BatchNorm2d-12           [-1, 64, 14, 14]             128
#              ReLU-13           [-1, 64, 14, 14]               0
#            Conv2d-14           [-1, 64, 14, 14]          36,864
#       BatchNorm2d-15           [-1, 64, 14, 14]             128
#              ReLU-16           [-1, 64, 14, 14]               0
#         MaxPool2d-17             [-1, 64, 7, 7]               0
#           Flatten-18                 [-1, 3136]               0
#            Linear-19                  [-1, 256]         803,072
#              ReLU-20                  [-1, 256]               0
#            Linear-21                   [-1, 64]          16,448
#              ReLU-22                   [-1, 64]               0
#           Dropout-23                   [-1, 64]               0
#            Linear-24                   [-1, 26]           1,690
# ================================================================
# Total params: 923,386
# Trainable params: 923,386
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.68
# Params size (MB): 3.52
# Estimated Total Size (MB): 5.21
# ----------------------------------------------------------------

# %%
#Training and saving the model

print("Training Model...")
epochs = 100
patience = 5
counter = 0
MinValLoss = float('inf')

for epoch in range(epochs):
	#Train Loop

	#Set model to training mode
	model.train()
	TrainLoss = 0.0

	for i,data in enumerate(TrainLoader,0):
		inputs,labels = data[0].to(device),data[1].to(device)

		#Zero the parameter gradients
		optimizer.zero_grad()

		#Forward pass
		outputs = model(inputs)

		#Calculate loss
		loss = loss_function(outputs,labels)

		#Backward pass
		loss.backward()

		#Update weights
		optimizer.step()

		#Update loss
		TrainLoss += loss.item()
	
	#Validation Loop
	model.eval()
	ValidationLoss = 0.0
	correct = 0
	total = 0

	with torch.no_grad():
		for data in TestLoader:
			images,labels = data[0].to(device),data[1].to(device)
			outputs = model(images)
			loss = loss_function(outputs,labels)
			ValidationLoss += loss.item()

			_,predicted = torch.max(outputs.data,1)
			total += labels.size(0)
			correct += (predicted == labels).sum().item()

		acc = 100*correct/total
		print(f"Epoch: {epoch+1}/{epochs} | "
			f"Training Loss: {TrainLoss/len(TrainLoader):.3f} | "
			f"Validation Loss: {ValidationLoss / len(TestLoader):.3f} | "
			f"Accuracy: {acc:.3f}%")
		scheduler.step(ValidationLoss)
		if ValidationLoss < MinValLoss:
			MinValLoss = ValidationLoss
			counter = 0
			torch.save(model.state_dict(),"EMNISTModel.pth")
			print(f"Validation Loss has improved at epoch {epoch+1}. Model Saved!")
		else:
			counter += 1
			print(f"Validation Loss has not improved. Patience:{counter}/{patience}")
		
		if counter >= patience:
			print("Early stopping triggered!")
			break
		
print("Training Complete")
# Out:
# Training Model...
# Epoch: 1/100 | Training Loss: 0.801 | Validation Loss: 0.036 | Accuracy: 99.270%
# Validation Loss has improved at epoch 1. Model Saved!
# Epoch: 2/100 | Training Loss: 0.127 | Validation Loss: 0.021 | Accuracy: 99.270%
# Validation Loss has improved at epoch 2. Model Saved!
# Epoch: 3/100 | Training Loss: 0.084 | Validation Loss: 0.019 | Accuracy: 99.544%
# Validation Loss has improved at epoch 3. Model Saved!
# Epoch: 4/100 | Training Loss: 0.070 | Validation Loss: 0.013 | Accuracy: 99.696%
# Validation Loss has improved at epoch 4. Model Saved!
# Epoch: 5/100 | Training Loss: 0.061 | Validation Loss: 0.017 | Accuracy: 99.514%
# Validation Loss has not improved. Patience:1/5
# Epoch: 6/100 | Training Loss: 0.053 | Validation Loss: 0.009 | Accuracy: 99.726%
# Validation Loss has improved at epoch 6. Model Saved!
# Epoch: 7/100 | Training Loss: 0.046 | Validation Loss: 0.016 | Accuracy: 99.605%
# Validation Loss has not improved. Patience:1/5
# Epoch: 8/100 | Training Loss: 0.047 | Validation Loss: 0.006 | Accuracy: 99.787%
# Validation Loss has improved at epoch 8. Model Saved!
# Epoch: 9/100 | Training Loss: 0.044 | Validation Loss: 0.015 | Accuracy: 99.574%
# Validation Loss has not improved. Patience:1/5
# Epoch: 10/100 | Training Loss: 0.043 | Validation Loss: 0.012 | Accuracy: 99.635%
# Validation Loss has not improved. Patience:2/5
# Epoch: 11/100 | Training Loss: 0.037 | Validation Loss: 0.016 | Accuracy: 99.574%
# Validation Loss has not improved. Patience:3/5
# Epoch: 12/100 | Training Loss: 0.030 | Validation Loss: 0.003 | Accuracy: 99.878%
# Validation Loss has improved at epoch 12. Model Saved!
# Epoch: 13/100 | Training Loss: 0.039 | Validation Loss: 0.006 | Accuracy: 99.878%
# Validation Loss has not improved. Patience:1/5
# Epoch: 14/100 | Training Loss: 0.034 | Validation Loss: 0.006 | Accuracy: 99.787%
# Validation Loss has not improved. Patience:2/5
# Epoch: 15/100 | Training Loss: 0.034 | Validation Loss: 0.005 | Accuracy: 99.787%
# Validation Loss has not improved. Patience:3/5
# Epoch: 16/100 | Training Loss: 0.034 | Validation Loss: 0.006 | Accuracy: 99.757%
# Validation Loss has not improved. Patience:4/5
# Epoch: 17/100 | Training Loss: 0.018 | Validation Loss: 0.003 | Accuracy: 99.878%
# Validation Loss has not improved. Patience:5/5
# Early stopping triggered!
# Training Complete

# %%
#Testing Model

print("Testing model with inbuilt dataset...")


		#Update loss
model.load_state_dict(torch.load("EMNISTModel.pth"))

TestLoss = 0.0
correct = 0
total = 0

with torch.no_grad():
	for images, labels in TestLoader:

		#Move data to device
		images,labels = images.to(device),labels.to(device)

		#Forward pass
		outputs = model(images)

		#Calculate loss
		loss = loss_function(outputs,labels)
		TestLoss += loss.item()

		#Get predicted class
		_,predicted = torch.max(outputs.data,1)

		#Update total and correct counts
		total += labels.size(0)
		correct += (predicted == labels).sum().item()
	
#Test Results

FinalLoss = TestLoss/len(TestLoader)
FinalAcc = 100*correct/total

print(f"Test Accuracy: {FinalAcc:.3f}%")
print(f"Test Loss: {FinalLoss:.3f}")
# Out:
# Testing model with inbuilt dataset...
# Test Accuracy: 99.878%
# Test Loss: 0.003
